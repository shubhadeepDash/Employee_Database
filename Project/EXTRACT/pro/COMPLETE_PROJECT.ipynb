# %%
import log_mod
log_mod.login_function()
# Out:
# -------WELCOME TO EMPLOYEE SYSTEM--------
#
# Please Enter Login ID:20HR25
# Please Enter Passoword:AKSHAT
#
# -----------WELCOME TO THE TO EMPLOYEE MODULE---------------
#
# Welcome, AKSHAT from HR!!!
# ENTER 1 - TO VIEW OWN DETAILS
# ENTER 2 - TO VIEW EMPLOYEES
# ENTER 3 - TO EXIT
# 1
# Employee_ID:20HR25
# Employee_Name:AKSHAT KUMAR
# Employee_DOJ:21/05/2021
# Employee_Designation:WEB DEVELOPER
# Employee_Salary:0
#
# ENTER 1 - TO VIEW OWN DETAILS
# ENTER 2 - TO VIEW EMPLOYEES
# ENTER 3 - TO EXIT
# 2
# Enter designation: SOFTWARE ENGINEER
# Employee_ID:65EP22
# Employee_Name:HARISH KUMAR
# Employee_DOJ:21/03/2021
# Employee_Designation:SOFTWARE ENGINEER
# Employee_Salary:0
#
# Employee_ID:20HR58
# Employee_Name:SHUBHADEEP DASH
# Employee_DOJ:26/03/2021
# Employee_Designation:SOFTWARE ENGINEER
# Employee_Salary:0
#
# ENTER 1 - TO VIEW OWN DETAILS
# ENTER 2 - TO VIEW EMPLOYEES
# ENTER 3 - TO EXIT
# 2
# Enter designation: WEB DEVELOPER
# Employee_ID:20EP21
# ...
